# %% [markdown]
# <a href="https://colab.research.google.com/github/Infant-Joshva/Data-Science-learning-path/blob/main/Mini_Project_1(Secure_check)Git/Mini_project_1(Secure_Check).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mini Project(Secure Check) Initialation and Data Cleaning

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

# %%
sheet_id= '16qEUKckLFy7j1qoSd1bSQURn9QXDb6ffSBAWzRkPsSg'
sheet_name = "sheet1"

#https://docs.google.com/spreadsheets/d/16qEUKckLFy7j1qoSd1bSQURn9QXDb6ffSBAWzRkPsSg/edit?gid=1282651194#gid=1282651194

url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"

traffic_df=pd.read_csv(url)
# Out:
# <ipython-input-4-3468746139>:8: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   traffic_df=pd.read_csv(url)

# %%
traffic_df.head(10)
# Out:
#    stop_date stop_time country_name driver_gender  driver_age_raw  driver_age  \
# 0 2020-01-01   0:00:00       Canada             M              59          19
# 1 2020-01-01   0:01:00        India             M              35          58
# 2 2020-01-01   0:02:00          USA             M              26          76
# 3 2020-01-01   0:03:00       Canada             M              26          76
# 4 2020-01-01   0:04:00       Canada             M              62          75
# 5 2020-01-01   0:05:00       Canada             F              44          73
# 6 2020-01-01   0:06:00          USA             F              80          70
# 7 2020-01-01   0:07:00        India             M              72          50
# 8 2020-01-01   0:08:00          USA             F              80          30
# 9 2020-01-01   0:09:00          USA             M              43          21
#
#   driver_race     violation_raw violation  search_conducted     search_type  \
# 0       Asian     Drunk Driving  Speeding              True  Vehicle Search
# 1       Other             Other     Other             False  Vehicle Search
# 2       Black  Signal Violation  Speeding             False           Frisk
# 3       Black          Speeding       DUI              True           Frisk
# 4       Other          Speeding     Other             False  Vehicle Search
# 5       Other     Drunk Driving     Other              True  Vehicle Search
# 6       White  Signal Violation  Speeding             False  Vehicle Search
# 7       Asian     Drunk Driving     Other             False             NaN
# 8    Hispanic             Other  Seatbelt              True           Frisk
# 9       Asian  Signal Violation    Signal              True             NaN
#
#   stop_outcome  is_arrested stop_duration  drugs_related_stop vehicle_number
# 0       Ticket         True     16-30 Min                True     UP76DY3473
# 1       Arrest         True     16-30 Min                True     RJ83PZ4441
# 2       Ticket         True     16-30 Min                True     RJ32OM7264
# 3      Warning        False      0-15 Min                True     RJ76TI3807
# 4       Arrest         True     16-30 Min               False     WB63BB8305
# 5       Ticket        False     16-30 Min               False     MH89ZF7676
# 6       Ticket        False       30+ Min               False     KA40AD3153
# 7       Arrest         True       30+ Min                True     DL75KZ7835
# 8       Arrest        False      0-15 Min                True     DL50PO5101
# 9      Warning         True     16-30 Min               False     KA79RD2271

# %% [markdown]
# ####Data Type conversion

# %%
traffic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65538 entries, 0 to 65537
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           65538 non-null  datetime64[ns]
#  1   stop_time           65538 non-null  object
#  2   country_name        65538 non-null  object
#  3   driver_gender       65538 non-null  object
#  4   driver_age_raw      65538 non-null  int64
#  5   driver_age          65538 non-null  int64
#  6   driver_race         65538 non-null  object
#  7   violation_raw       65538 non-null  object
#  8   violation           65538 non-null  object
#  9   search_conducted    65538 non-null  bool
#  10  search_type         43818 non-null  object
#  11  stop_outcome        65538 non-null  object
#  12  is_arrested         65538 non-null  bool
#  13  stop_duration       65538 non-null  object
#  14  drugs_related_stop  65538 non-null  bool
#  15  vehicle_number      65538 non-null  object
# dtypes: bool(3), datetime64[ns](1), int64(2), object(10)
# memory usage: 6.7+ MB

# %%
traffic_df['stop_date']=pd.to_datetime(traffic_df['stop_date'])

# %%
traffic_df['stop_time'] = pd.to_datetime(traffic_df['stop_time'], format='%H:%M:%S').dt.time
# Out:
# 0        00:00:00
# 1        00:01:00
# 2        00:02:00
# 3        00:03:00
# 4        00:04:00
#            ...
# 65533    12:13:00
# 65534    12:14:00
# 65535    12:15:00
# 65536    12:16:00
# 65537    12:17:00
# Name: stop_time, Length: 65538, dtype: object

# %% [markdown]
# ####Handling Null Values

# %%
traffic_df.isnull().sum()
# Out:
# stop_date             0
# stop_time             0
# country_name          0
# driver_gender         0
# driver_age_raw        0
# driver_age            0
# driver_race           0
# violation_raw         0
# violation             0
# search_conducted      0
# search_type           0
# stop_outcome          0
# is_arrested           0
# stop_duration         0
# drugs_related_stop    0
# vehicle_number        0
# dtype: int64

# %%
traffic_df['search_type'].value_counts(dropna=False)
# Out:
# search_type
# Frisk             21971
# Vehicle Search    21847
# None              21720
# Name: count, dtype: int64

# %%
traffic_df.head(10)
# Out:
#    stop_date stop_time country_name driver_gender  driver_age_raw  driver_age  \
# 0 2020-01-01   0:00:00       Canada             M              59          19
# 1 2020-01-01   0:01:00        India             M              35          58
# 2 2020-01-01   0:02:00          USA             M              26          76
# 3 2020-01-01   0:03:00       Canada             M              26          76
# 4 2020-01-01   0:04:00       Canada             M              62          75
# 5 2020-01-01   0:05:00       Canada             F              44          73
# 6 2020-01-01   0:06:00          USA             F              80          70
# 7 2020-01-01   0:07:00        India             M              72          50
# 8 2020-01-01   0:08:00          USA             F              80          30
# 9 2020-01-01   0:09:00          USA             M              43          21
#
#   driver_race     violation_raw violation  search_conducted     search_type  \
# 0       Asian     Drunk Driving  Speeding              True  Vehicle Search
# 1       Other             Other     Other             False  Vehicle Search
# 2       Black  Signal Violation  Speeding             False           Frisk
# 3       Black          Speeding       DUI              True           Frisk
# 4       Other          Speeding     Other             False  Vehicle Search
# 5       Other     Drunk Driving     Other              True  Vehicle Search
# 6       White  Signal Violation  Speeding             False  Vehicle Search
# 7       Asian     Drunk Driving     Other             False             NaN
# 8    Hispanic             Other  Seatbelt              True           Frisk
# 9       Asian  Signal Violation    Signal              True             NaN
#
#   stop_outcome  is_arrested stop_duration  drugs_related_stop vehicle_number
# 0       Ticket         True     16-30 Min                True     UP76DY3473
# 1       Arrest         True     16-30 Min                True     RJ83PZ4441
# 2       Ticket         True     16-30 Min                True     RJ32OM7264
# 3      Warning        False      0-15 Min                True     RJ76TI3807
# 4       Arrest         True     16-30 Min               False     WB63BB8305
# 5       Ticket        False     16-30 Min               False     MH89ZF7676
# 6       Ticket        False       30+ Min               False     KA40AD3153
# 7       Arrest         True       30+ Min                True     DL75KZ7835
# 8       Arrest        False      0-15 Min                True     DL50PO5101
# 9      Warning         True     16-30 Min               False     KA79RD2271

# %%
traffic_df.loc[traffic_df['search_type'].isna(),'search_type']='None' #Replace Nan to None

# %%
traffic_df['country_name'].value_counts()
# Out:
# country_name
# India     21998
# Canada    21908
# USA       21632
# Name: count, dtype: int64

# %%
traffic_df['driver_gender'].value_counts()
# Out:
# driver_gender
# F    32881
# M    32657
# Name: count, dtype: int64

# %%
traffic_df['driver_age_raw'].value_counts()
# Out:
# driver_age_raw
# 75    1134
# 50    1100
# 41    1089
# 40    1083
# 59    1080
#       ...
# 44     987
# 65     986
# 78     986
# 25     981
# 47     980
# Name: count, Length: 63, dtype: int64

# %%
traffic_df['driver_race'].value_counts()
# Out:
# driver_race
# White       13168
# Black       13131
# Other       13122
# Asian       13111
# Hispanic    13006
# Name: count, dtype: int64

# %%
traffic_df['violation_raw'].value_counts()
# Out:
# violation_raw
# Seatbelt            13204
# Speeding            13148
# Signal Violation    13113
# Drunk Driving       13094
# Other               12979
# Name: count, dtype: int64

# %%
traffic_df['violation'].value_counts()
# Out:
# violation
# Other       13194
# Speeding    13150
# Signal      13112
# DUI         13075
# Seatbelt    13007
# Name: count, dtype: int64

# %%
traffic_df['search_conducted'].value_counts()
# Out:
# search_conducted
# False    32837
# True     32701
# Name: count, dtype: int64

# %%
traffic_df['search_type'].value_counts()
# Out:
# search_type
# Frisk             21971
# Vehicle Search    21847
# None              21720
# Name: count, dtype: int64

# %%
traffic_df['stop_outcome'].value_counts()
# Out:
# stop_outcome
# Warning    21966
# Ticket     21838
# Arrest     21734
# Name: count, dtype: int64

# %%
traffic_df['is_arrested'].value_counts()
# Out:
# is_arrested
# True     32846
# False    32692
# Name: count, dtype: int64

# %%
traffic_df['stop_duration'].value_counts()
# Out:
# stop_duration
# 30+ Min      21958
# 0-15 Min     21831
# 16-30 Min    21749
# Name: count, dtype: int64

# %%
traffic_df['drugs_related_stop'].value_counts()
# Out:
# drugs_related_stop
# True     32769
# False    32769
# Name: count, dtype: int64

# %%
traffic_df['vehicle_number'].value_counts()
# Out:
# vehicle_number
# UP89PT2924    1
# UP76DY3473    1
# MH42PF3736    1
# UP10NB3599    1
# GJ34FX6230    1
#              ..
# KA40AD3153    1
# MH89ZF7676    1
# WB63BB8305    1
# RJ76TI3807    1
# RJ32OM7264    1
# Name: count, Length: 65538, dtype: int64

# %% [markdown]
# ####Deleting Unwanted Row

# %%
traffic_df.drop(['driver_age'], axis=1, inplace=True)  # if you only use cleaned age

# %%
traffic_df.head(10)
# Out:
#    stop_date stop_time country_name driver_gender  driver_age_raw driver_race  \
# 0 2020-01-01   0:00:00       Canada             M              59       Asian
# 1 2020-01-01   0:01:00        India             M              35       Other
# 2 2020-01-01   0:02:00          USA             M              26       Black
# 3 2020-01-01   0:03:00       Canada             M              26       Black
# 4 2020-01-01   0:04:00       Canada             M              62       Other
# 5 2020-01-01   0:05:00       Canada             F              44       Other
# 6 2020-01-01   0:06:00          USA             F              80       White
# 7 2020-01-01   0:07:00        India             M              72       Asian
# 8 2020-01-01   0:08:00          USA             F              80    Hispanic
# 9 2020-01-01   0:09:00          USA             M              43       Asian
#
#       violation_raw violation  search_conducted     search_type stop_outcome  \
# 0     Drunk Driving  Speeding              True  Vehicle Search       Ticket
# 1             Other     Other             False  Vehicle Search       Arrest
# 2  Signal Violation  Speeding             False           Frisk       Ticket
# 3          Speeding       DUI              True           Frisk      Warning
# 4          Speeding     Other             False  Vehicle Search       Arrest
# 5     Drunk Driving     Other              True  Vehicle Search       Ticket
# 6  Signal Violation  Speeding             False  Vehicle Search       Ticket
# 7     Drunk Driving     Other             False            None       Arrest
# 8             Other  Seatbelt              True           Frisk       Arrest
# 9  Signal Violation    Signal              True            None      Warning
#
#    is_arrested stop_duration  drugs_related_stop vehicle_number
# 0         True     16-30 Min                True     UP76DY3473
# 1         True     16-30 Min                True     RJ83PZ4441
# 2         True     16-30 Min                True     RJ32OM7264
# 3        False      0-15 Min                True     RJ76TI3807
# 4         True     16-30 Min               False     WB63BB8305
# 5        False     16-30 Min               False     MH89ZF7676
# 6        False       30+ Min               False     KA40AD3153
# 7         True       30+ Min                True     DL75KZ7835
# 8        False      0-15 Min                True     DL50PO5101
# 9         True     16-30 Min               False     KA79RD2271

# %% [markdown]
# ####Deleting Duplicate Values

# %%
traffic_df.drop_duplicates(inplace=True) #Used to drop the duplicate values

# %%
traffic_df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ####Storing Cleaned Data to SQL

# %%
from sqlalchemy import create_engine, inspect
engine=create_engine(db_url) # Importing necessary packages from pandas

# %%
db_url="postgresql://infant:5kV8T4PGM0C3pHexclSBZU80ijwqBMxn@dpg-d0mmus3e5dus738lfkgg-a.singapore-postgres.render.com/traffic" #Database Connection, Host Name, Password, Database Name

# %%
traffic_df.to_sql('traffic_stop',engine,index=False,if_exists='replace') # Creating New Table and storing the cleaned data into SQL
# Out:
# 538

# %%
query = """SELECT * FROM traffic_stop"""

filtered_df = pd.read_sql(query,engine)
filtered_df
# Out:
#        stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0     2020-01-01   0:00:00       Canada             M              59
# 1     2020-01-01   0:01:00        India             M              35
# 2     2020-01-01   0:02:00          USA             M              26
# 3     2020-01-01   0:03:00       Canada             M              26
# 4     2020-01-01   0:04:00       Canada             M              62
# ...          ...       ...          ...           ...             ...
# 65533 2020-02-15  12:13:00        India             F              54
# 65534 2020-02-15  12:14:00       Canada             F              18
# 65535 2020-02-15  12:15:00          USA             M              27
# 65536 2020-02-15  12:16:00       Canada             F              49
# 65537 2020-02-15  12:17:00          USA             F              72
#
#       driver_race     violation_raw violation  search_conducted  \
# 0           Asian     Drunk Driving  Speeding              True
# 1           Other             Other     Other             False
# 2           Black  Signal Violation  Speeding             False
# 3           Black          Speeding       DUI              True
# 4           Other          Speeding     Other             False
# ...           ...               ...       ...               ...
# 65533       Black             Other     Other             False
# 65534    Hispanic          Seatbelt     Other              True
# 65535       Asian          Seatbelt       DUI              True
# 65536       Black          Seatbelt     Other             False
# 65537       Other          Seatbelt  Speeding              True
#
#           search_type stop_outcome  is_arrested stop_duration  \
# 0      Vehicle Search       Ticket         True     16-30 Min
# 1      Vehicle Search       Arrest         True     16-30 Min
# 2               Frisk       Ticket         True     16-30 Min
# 3               Frisk      Warning        False      0-15 Min
# 4      Vehicle Search       Arrest         True     16-30 Min
# ...               ...          ...          ...           ...
# 65533  Vehicle Search       Arrest         True     16-30 Min
# 65534  Vehicle Search       Ticket        False     16-30 Min
# 65535           Frisk       Ticket         True       30+ Min
# 65536            None      Warning         True      0-15 Min
# 65537            None       Ticket         True     16-30 Min
#
#        drugs_related_stop vehicle_number
# 0                    True     UP76DY3473
# 1                    True     RJ83PZ4441
# 2                    True     RJ32OM7264
# 3                    True     RJ76TI3807
# 4                   False     WB63BB8305
# ...                   ...            ...
# 65533               False     DL56GW6568
# 65534                True     TN73EO7098
# 65535                True     GJ33MX8328
# 65536                True     KA24UZ8488
# 65537               False     UP89PT2924
#
# [65538 rows x 15 columns]

# %%
traffic_df.to_csv('cleaned_traffic_stop.csv', index=False)
