# %%
video_path="https://youtube.com/shorts/D5VJfVSfTNI?si=pLjlVBiZwrHxDzJb"

# %%
#Code to download the youtube video

from pytubefix import YouTube

# %%
yt = YouTube(video_path)
stream = yt.streams.filter(file_extension='mp4', res='1080p').first()
stream.download(filename="bold_washer.mp4")
# Out:
# 'c:\\Users\\infan\\OneDrive\\Desktop\\Data Science Guvi Py(Git)\\Data-Science-learning-path\\DS-Practice-Notebooks\\DS04-DL-NLP\\Computer_vision\\bold_washer.mp4'
