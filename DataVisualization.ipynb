# %% [markdown]
# <a href="https://colab.research.google.com/github/Infant-Joshva/Data-Science-learning-path/blob/main/DataVisualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Visualization

# %%
import pandas as pd

# %%
# !unzip /content/Cleaned_dataset.csv.zip
# Out:
# Archive:  /content/Cleaned_dataset.csv.zip
#   inflating: Cleaned_dataset.csv

# %%
df=pd.read_csv('/content/Cleaned_dataset.csv')
df.head()
# Out:
#   Date_of_journey Journey_day    Airline Flight_code    Class Source  \
# 0      2023-01-16      Monday   SpiceJet     SG-8169  Economy  Delhi
# 1      2023-01-16      Monday     Indigo     6E-2519  Economy  Delhi
# 2      2023-01-16      Monday   GO FIRST      G8-354  Economy  Delhi
# 3      2023-01-16      Monday   SpiceJet     SG-8709  Economy  Delhi
# 4      2023-01-16      Monday  Air India      AI-805  Economy  Delhi
#
#     Departure Total_stops      Arrival Destination  Duration_in_hours  \
# 0  After 6 PM    non-stop   After 6 PM      Mumbai             2.0833
# 1  After 6 PM    non-stop  Before 6 AM      Mumbai             2.3333
# 2  After 6 PM    non-stop  Before 6 AM      Mumbai             2.1667
# 3  After 6 PM    non-stop   After 6 PM      Mumbai             2.0833
# 4  After 6 PM    non-stop   After 6 PM      Mumbai             2.1667
#
#    Days_left  Fare
# 0          1  5335
# 1          1  5899
# 2          1  5801
# 3          1  5794
# 4          1  5955

# %%
df.shape
# Out:
# (452088, 13)

# %%
df.isnull().sum()
# Out:
# Date_of_journey      0
# Journey_day          0
# Airline              0
# Flight_code          0
# Class                0
# Source               0
# Departure            0
# Total_stops          0
# Arrival              0
# Destination          0
# Duration_in_hours    0
# Days_left            0
# Fare                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(6722)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (445366, 13)

# %%
df
# Out:
#        Date_of_journey Journey_day    Airline Flight_code     Class  \
# 0           2023-01-16      Monday   SpiceJet     SG-8169   Economy
# 1           2023-01-16      Monday     Indigo     6E-2519   Economy
# 2           2023-01-16      Monday   GO FIRST      G8-354   Economy
# 3           2023-01-16      Monday   SpiceJet     SG-8709   Economy
# 4           2023-01-16      Monday  Air India      AI-805   Economy
# ...                ...         ...        ...         ...       ...
# 452081      2023-03-06      Monday    Vistara      UK-918  Business
# 452082      2023-03-06      Monday    Vistara      UK-946  Business
# 452083      2023-03-06      Monday    Vistara      UK-926  Business
# 452084      2023-03-06      Monday    Vistara      UK-918  Business
# 452086      2023-03-06      Monday    Vistara      UK-946  Business
#
#            Source     Departure Total_stops       Arrival Destination  \
# 0           Delhi    After 6 PM    non-stop    After 6 PM      Mumbai
# 1           Delhi    After 6 PM    non-stop   Before 6 AM      Mumbai
# 2           Delhi    After 6 PM    non-stop   Before 6 AM      Mumbai
# 3           Delhi    After 6 PM    non-stop    After 6 PM      Mumbai
# 4           Delhi    After 6 PM    non-stop    After 6 PM      Mumbai
# ...           ...           ...         ...           ...         ...
# 452081  Ahmedabad   Before 6 AM      1-stop  12 PM - 6 PM     Chennai
# 452082  Ahmedabad  6 AM - 12 PM      1-stop    After 6 PM     Chennai
# 452083  Ahmedabad  6 AM - 12 PM      1-stop    After 6 PM     Chennai
# 452084  Ahmedabad   Before 6 AM      1-stop  12 PM - 6 PM     Chennai
# 452086  Ahmedabad  6 AM - 12 PM      1-stop    After 6 PM     Chennai
#
#         Duration_in_hours  Days_left   Fare
# 0                  2.0833          1   5335
# 1                  2.3333          1   5899
# 2                  2.1667          1   5801
# 3                  2.0833          1   5794
# 4                  2.1667          1   5955
# ...                   ...        ...    ...
# 452081            11.2500         50  61302
# 452082            11.1667         50  65028
# 452083            13.0833         50  65028
# 452084            11.2500         50  69254
# 452086            11.1667         50  72980
#
# [445366 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 445366 entries, 0 to 452086
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Date_of_journey    445366 non-null  object
#  1   Journey_day        445366 non-null  object
#  2   Airline            445366 non-null  object
#  3   Flight_code        445366 non-null  object
#  4   Class              445366 non-null  object
#  5   Source             445366 non-null  object
#  6   Departure          445366 non-null  object
#  7   Total_stops        445366 non-null  object
#  8   Arrival            445366 non-null  object
#  9   Destination        445366 non-null  object
#  10  Duration_in_hours  445366 non-null  float64
#  11  Days_left          445366 non-null  int64
#  12  Fare               445366 non-null  int64
# dtypes: float64(1), int64(2), object(10)
# memory usage: 47.6+ MB

# %%
df.dtypes
# Out:
# Date_of_journey       object
# Journey_day           object
# Airline               object
# Flight_code           object
# Class                 object
# Source                object
# Departure             object
# Total_stops           object
# Arrival               object
# Destination           object
# Duration_in_hours    float64
# Days_left              int64
# Fare                   int64
# dtype: object

# %%
df['Date_of_journey'] = pd.to_datetime(df['Date_of_journey'])

# %%
df['Journey_day'].value_counts()
# Out:
# Journey_day
# Monday       71194
# Thursday     63157
# Friday       63035
# Wednesday    62698
# Tuesday      62379
# Saturday     61624
# Sunday       61279
# Name: count, dtype: int64

# %%
df['Airline'].value_counts()
# Out:
# Airline
# Vistara        226204
# Air India      118405
# Indigo          65659
# AirAsia         15764
# GO FIRST        10786
# SpiceJet         5863
# AkasaAir         2230
# AllianceAir       393
# StarAir            62
# Name: count, dtype: int64

# %%
df['Flight_code'].value_counts()
# Out:
# Flight_code
# UK-936     5117
# UK-706     4957
# UK-918     4912
# UK-926     4388
# UK-832     4244
#            ...
# 6E-251        1
# 6E-3291       1
# 6E-6835       1
# G8-911        1
# 6E-983        1
# Name: count, Length: 1405, dtype: int64

# %%
df['Class'].value_counts()
# Out:
# Class
# Economy            248323
# Business           126535
# Premium Economy     70364
# First                 144
# Name: count, dtype: int64

# %%
df['Source'].value_counts()
# Out:
# Source
# Delhi        82481
# Mumbai       79894
# Bangalore    72668
# Hyderabad    56054
# Chennai      55659
# Kolkata      54193
# Ahmedabad    44417
# Name: count, dtype: int64

# %%
df['Departure'].value_counts()
# Out:
# Departure
# 6 AM - 12 PM    181019
# After 6 PM      126749
# 12 PM - 6 PM    114743
# Before 6 AM      22855
# Name: count, dtype: int64

# %%
df['Total_stops'].value_counts()
# Out:
# Total_stops
# 1-stop      366527
# non-stop     51755
# 2+-stop      27084
# Name: count, dtype: int64

# %%
df['Total_stops'].value_counts()
# Out:
# Total_stops
# 1-stop      366527
# non-stop     51755
# 2+-stop      27084
# Name: count, dtype: int64

# %%
df['Arrival'].value_counts()
# Out:
# Arrival
# After 6 PM      196972
# 6 AM - 12 PM    117665
# 12 PM - 6 PM    100322
# Before 6 AM      30407
# Name: count, dtype: int64

# %%
df['Destination'].value_counts()
# Out:
# Destination
# Mumbai       81675
# Delhi        76758
# Bangalore    71603
# Hyderabad    61775
# Chennai      57060
# Kolkata      53465
# Ahmedabad    43030
# Name: count, dtype: int64

# %%
df['Destination'].value_counts()
# Out:
# Destination
# Mumbai       81675
# Delhi        76758
# Bangalore    71603
# Hyderabad    61775
# Chennai      57060
# Kolkata      53465
# Ahmedabad    43030
# Name: count, dtype: int64

# %% [markdown]
# # Univarient Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 445366 entries, 0 to 452086
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Date_of_journey    445366 non-null  datetime64[ns]
#  1   Journey_day        445366 non-null  object
#  2   Airline            445366 non-null  object
#  3   Flight_code        445366 non-null  object
#  4   Class              445366 non-null  object
#  5   Source             445366 non-null  object
#  6   Departure          445366 non-null  object
#  7   Total_stops        445366 non-null  object
#  8   Arrival            445366 non-null  object
#  9   Destination        445366 non-null  object
#  10  Duration_in_hours  445366 non-null  float64
#  11  Days_left          445366 non-null  int64
#  12  Fare               445366 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(9)
# memory usage: 47.6+ MB

# %% [markdown]
# ## Numerical

# %%
df['Duration_in_hours'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['Duration_in_hours'])

# %%
plt.hist(df['Duration_in_hours'],bins=20)
# Out:
# (array([47523., 18494., 66608., 48328., 48289., 50157., 43859., 30486.,
#         16407., 16513., 22359., 19913., 10285.,  1916.,  1638.,  1088.,
#           843.,   362.,   177.,   121.]),
#  array([ 0.75    ,  2.891665,  5.03333 ,  7.174995,  9.31666 , 11.458325,
#         13.59999 , 15.741655, 17.88332 , 20.024985, 22.16665 , 24.308315,
#         26.44998 , 28.591645, 30.73331 , 32.874975, 35.01664 , 37.158305,
#         39.29997 , 41.441635, 43.5833  ]),
#  <BarContainer object of 20 artists>)

# %%
plt.figure(figsize=(10,5))
plt.hist(df['Duration_in_hours'],bins=20)
# Out:
# (array([47523., 18494., 66608., 48328., 48289., 50157., 43859., 30486.,
#         16407., 16513., 22359., 19913., 10285.,  1916.,  1638.,  1088.,
#           843.,   362.,   177.,   121.]),
#  array([ 0.75    ,  2.891665,  5.03333 ,  7.174995,  9.31666 , 11.458325,
#         13.59999 , 15.741655, 17.88332 , 20.024985, 22.16665 , 24.308315,
#         26.44998 , 28.591645, 30.73331 , 32.874975, 35.01664 , 37.158305,
#         39.29997 , 41.441635, 43.5833  ]),
#  <BarContainer object of 20 artists>)

# %%
plt.figure(figsize=(10,5))
plt.hist(df['Duration_in_hours'],bins=25,edgecolor='black')
# Out:
# (array([37371., 17553., 34552., 55750., 35727., 36520., 41371., 39388.,
#         34867., 20645., 13193., 12289., 16966., 15887., 16857.,  8935.,
#          2435.,  1668.,   973.,   916.,   723.,   345.,   214.,   160.,
#            61.]),
#  array([ 0.75    ,  2.463332,  4.176664,  5.889996,  7.603328,  9.31666 ,
#         11.029992, 12.743324, 14.456656, 16.169988, 17.88332 , 19.596652,
#         21.309984, 23.023316, 24.736648, 26.44998 , 28.163312, 29.876644,
#         31.589976, 33.303308, 35.01664 , 36.729972, 38.443304, 40.156636,
#         41.869968, 43.5833  ]),
#  <BarContainer object of 25 artists>)

# %%
plt.figure(figsize=(10,5))
plt.hist(df['Duration_in_hours'],bins=25,edgecolor='black')
plt.xlabel('Duration_in_hours')
plt.ylabel('Frequency')
plt.title('Distribution of Duration_in_hours')
# Out:
# Text(0.5, 1.0, 'Distribution of Duration_in_hours')

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.11/dist-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.11/dist-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
import seaborn as sns

# %%
sns.kdeplot(df['Duration_in_hours']) #Density plot
# Out:
# <Axes: xlabel='Duration_in_hours', ylabel='Density'>

# %%
sns.distplot(df['Duration_in_hours']) #Distribution plot(Combine both Histogram + Density plot)
# Out:
# /tmp/ipython-input-53-212484694.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Duration_in_hours']) #Distribution plot(Combine both Histogram + Density plot)
# <Axes: xlabel='Duration_in_hours', ylabel='Density'>

# %%
sns.distplot(df, x=df['Duration_in_hours']) #Another way to call the distribution plot
# Out:
# /tmp/ipython-input-38-3865931118.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df, x=df['Duration_in_hours']) #Another way to call the distribution plot
# <Axes: ylabel='Density'>

# %%
sns.distplot(df,x=df['Duration_in_hours'],color='Red')
plt.xlabel('Duration_in_hours') #Using Matplotlib to Edit the X axsis
plt.ylabel('Frequency') #Using Matplotlib to Edit the Y axsis
plt.title('Distribution of Duration_in_hours')
plt.show()
# Out:
# /tmp/ipython-input-39-1488173479.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df,x=df['Duration_in_hours'],color='Red')

# %%
plt.figure(figsize=(15,10))
sns.distplot(df,x=df['Duration_in_hours'],color='Red')
plt.xlabel('Duration_in_hours')
plt.ylabel('Frequency')
plt.title('Distribution of Duration_in_hours')
plt.annotate('Most Frequent Hour', xy=(8, 0.07), xytext=(20, 0.06),
             arrowprops=dict(facecolor='black', shrink=0.025),
             )

plt.show()
# Out:
# /tmp/ipython-input-40-1718016056.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df,x=df['Duration_in_hours'],color='Red')

# %%
plt.figure(figsize=(15,10))
plt.boxplot(df['Duration_in_hours'],vert=False)
plt.xlabel('Duration_in_hours')
plt.ylabel('Frequency')
plt.title('Distribution of Duration_in_hours')
# Out:
# Text(0.5, 1.0, 'Distribution of Duration_in_hours')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 445366 entries, 0 to 452086
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Date_of_journey    445366 non-null  datetime64[ns]
#  1   Journey_day        445366 non-null  object
#  2   Airline            445366 non-null  object
#  3   Flight_code        445366 non-null  object
#  4   Class              445366 non-null  object
#  5   Source             445366 non-null  object
#  6   Departure          445366 non-null  object
#  7   Total_stops        445366 non-null  object
#  8   Arrival            445366 non-null  object
#  9   Destination        445366 non-null  object
#  10  Duration_in_hours  445366 non-null  float64
#  11  Days_left          445366 non-null  int64
#  12  Fare               445366 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(9)
# memory usage: 47.6+ MB

# %% [markdown]
# #### Task for numerical data(Histogram in Matplotlib)

# %%
plt.figure(figsize=(15,10))
sns.distplot(df,x=df['Duration_in_hours'],color='Red')
plt.xlabel('Duration_in_hours')
plt.ylabel('Frequency')
plt.title('Distribution of Duration_in_hours')
plt.annotate('Most Frequent Hour', xy=(8, 0.07), xytext=(20, 0.06),
             arrowprops=dict(facecolor='black', shrink=0.025),
             )

plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 445366 entries, 0 to 452086
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Date_of_journey    445366 non-null  datetime64[ns]
#  1   Journey_day        445366 non-null  object
#  2   Airline            445366 non-null  object
#  3   Flight_code        445366 non-null  object
#  4   Class              445366 non-null  object
#  5   Source             445366 non-null  object
#  6   Departure          445366 non-null  object
#  7   Total_stops        445366 non-null  object
#  8   Arrival            445366 non-null  object
#  9   Destination        445366 non-null  object
#  10  Duration_in_hours  445366 non-null  float64
#  11  Days_left          445366 non-null  int64
#  12  Fare               445366 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(9)
# memory usage: 47.6+ MB

# %%
plt.figure(figsize=(10,5))
plt.hist(df['Date_of_journey'],edgecolor='black')
plt.xlabel('Date_of_journey')
plt.ylabel('Frequency')
plt.title('Distribution of Date_of_journey')
# Out:
# Text(0.5, 1.0, 'Distribution of Date_of_journey')

# %%
plt.figure(figsize=(10,5))
plt.hist(df['Days_left'],bins=50,edgecolor='black')
plt.xlabel('Days_left')
plt.ylabel('Frequency')
plt.title('Distribution of Days_left')
# Out:
# Text(0.5, 1.0, 'Distribution of Days_left')

# %%
plt.figure(figsize=(10,5))
plt.hist(df['Fare'],bins=35,edgecolor='black')
plt.xlabel('Fare')
plt.ylabel('Frequency')
plt.title('Distribution of Fare')
# Out:
# Text(0.5, 1.0, 'Distribution of Fare')

# %% [markdown]
# #### Task for numerical data(Density in Matplotlib)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 445366 entries, 0 to 452086
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Date_of_journey    445366 non-null  datetime64[ns]
#  1   Journey_day        445366 non-null  object
#  2   Airline            445366 non-null  object
#  3   Flight_code        445366 non-null  object
#  4   Class              445366 non-null  object
#  5   Source             445366 non-null  object
#  6   Departure          445366 non-null  object
#  7   Total_stops        445366 non-null  object
#  8   Arrival            445366 non-null  object
#  9   Destination        445366 non-null  object
#  10  Duration_in_hours  445366 non-null  float64
#  11  Days_left          445366 non-null  int64
#  12  Fare               445366 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(9)
# memory usage: 47.6+ MB

# %%
#Using Seaborn
plt.figure(figsize=(15,5))
sns.kdeplot(df['Date_of_journey'])
# Out:
# <Axes: xlabel='Date_of_journey', ylabel='Density'>

# %%
sns.kdeplot(df['Days_left'])
# Out:
# <Axes: xlabel='Days_left', ylabel='Density'>

# %%
sns.kdeplot(df['Fare'])
# Out:
# <Axes: xlabel='Fare', ylabel='Density'>

# %% [markdown]
# #### Task for numerical data - Distribution plot(Combine both Histogram + Density plot)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 445366 entries, 0 to 452086
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Date_of_journey    445366 non-null  datetime64[ns]
#  1   Journey_day        445366 non-null  object
#  2   Airline            445366 non-null  object
#  3   Flight_code        445366 non-null  object
#  4   Class              445366 non-null  object
#  5   Source             445366 non-null  object
#  6   Departure          445366 non-null  object
#  7   Total_stops        445366 non-null  object
#  8   Arrival            445366 non-null  object
#  9   Destination        445366 non-null  object
#  10  Duration_in_hours  445366 non-null  float64
#  11  Days_left          445366 non-null  int64
#  12  Fare               445366 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(9)
# memory usage: 47.6+ MB

# %%
sns.distplot(df['Duration_in_hours']) #Distribution plot(Combine both Histogram + Density plot)
# Out:
# /tmp/ipython-input-80-212484694.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Duration_in_hours']) #Distribution plot(Combine both Histogram + Density plot)
# <Axes: xlabel='Duration_in_hours', ylabel='Density'>

# %%
sns.distplot(df['Days_left']) #Distribution plot(Combine both Histogram + Density plot)
# Out:
# /tmp/ipython-input-81-2424574065.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Days_left']) #Distribution plot(Combine both Histogram + Density plot)
# <Axes: xlabel='Days_left', ylabel='Density'>

# %%
sns.distplot(df['Fare']) #Distribution plot(Combine both Histogram + Density plot)
# Out:
# /tmp/ipython-input-82-1671481889.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Fare']) #Distribution plot(Combine both Histogram + Density plot)
# <Axes: xlabel='Fare', ylabel='Density'>

# %% [markdown]
# #### Task for numerical data - Box plot

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 445366 entries, 0 to 452086
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Date_of_journey    445366 non-null  datetime64[ns]
#  1   Journey_day        445366 non-null  object
#  2   Airline            445366 non-null  object
#  3   Flight_code        445366 non-null  object
#  4   Class              445366 non-null  object
#  5   Source             445366 non-null  object
#  6   Departure          445366 non-null  object
#  7   Total_stops        445366 non-null  object
#  8   Arrival            445366 non-null  object
#  9   Destination        445366 non-null  object
#  10  Duration_in_hours  445366 non-null  float64
#  11  Days_left          445366 non-null  int64
#  12  Fare               445366 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(9)
# memory usage: 47.6+ MB

# %%
plt.figure(figsize=(15,5))
plt.boxplot(df['Days_left'],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7deb1c07d590>,
#   <matplotlib.lines.Line2D at 0x7deb1c9d2e50>],
#  'caps': [<matplotlib.lines.Line2D at 0x7deb1d87f2d0>,
#   <matplotlib.lines.Line2D at 0x7deb1c13c450>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7deb1c07c910>],
#  'medians': [<matplotlib.lines.Line2D at 0x7deb1c13e750>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7deb1c13cf90>],
#  'means': []}

# %%
plt.figure(figsize=(15,5))
plt.boxplot(df['Fare'],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7deb1c0db0d0>,
#   <matplotlib.lines.Line2D at 0x7deb1dac7e50>],
#  'caps': [<matplotlib.lines.Line2D at 0x7deb1dac6410>,
#   <matplotlib.lines.Line2D at 0x7deb1dac7510>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7deb1c0d9d90>],
#  'medians': [<matplotlib.lines.Line2D at 0x7deb1dac5950>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7deb1dac4c10>],
#  'means': []}

# %% [markdown]
# ## Categorical

# %%
df['Airline'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Airline'>

# %%
plt.figure(figsize=(15,10))
df['Airline'].value_counts().plot(kind='bar')
plt.xlabel('Airline')
plt.ylabel('Frequency')
plt.title('Distribution of Airline')
plt.show()

# %%
df['Airline'].value_counts().index
# Out:
# Index(['Vistara', 'Air India', 'Indigo', 'AirAsia', 'GO FIRST', 'SpiceJet',
#        'AkasaAir', 'AllianceAir', 'StarAir'],
#       dtype='object', name='Airline')

# %%
df['Airline'].value_counts()
# Out:
# Airline
# Vistara        226204
# Air India      118405
# Indigo          65659
# AirAsia         15764
# GO FIRST        10786
# SpiceJet         5863
# AkasaAir         2230
# AllianceAir       393
# StarAir            62
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,10))
plt.bar(df['Airline'].value_counts().index,df['Airline'].value_counts())
plt.xlabel('Airline')
plt.ylabel('Frequency')
plt.title('Distribution of Airline')
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(df,x='Airline')
plt.xlabel('Airline')
plt.ylabel('Frequency')
plt.title('Distribution of Airline')
plt.show()

# %%
df['Airline'].value_counts()
# Out:
# Airline
# Vistara        226204
# Air India      118405
# Indigo          65659
# AirAsia         15764
# GO FIRST        10786
# SpiceJet         5863
# AkasaAir         2230
# AllianceAir       393
# StarAir            62
# Name: count, dtype: int64

# %%
df['Airline'].value_counts().index
# Out:
# Index(['Vistara', 'Air India', 'Indigo', 'AirAsia', 'GO FIRST', 'SpiceJet',
#        'AkasaAir', 'AllianceAir', 'StarAir'],
#       dtype='object', name='Airline')

# %%
plt.figure(figsize=(15,10))
sns.countplot(df,x='Airline',order=df['Airline'].value_counts().index)
plt.xlabel('Airline')
plt.ylabel('Frequency')
plt.title('Distribution of Airline')
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(df,x='Airline',order=df['Airline'].value_counts().index,color='Red')
plt.xlabel('Airline')
plt.ylabel('Frequency')
plt.title('Distribution of Airline')
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(df,x='Airline',order=df['Airline'].value_counts().index,palette='light:#5A9')
plt.xlabel('Airline')
plt.ylabel('Frequency')
plt.title('Distribution of Airline')
plt.show()
# Out:
# /tmp/ipython-input-52-2809036560.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df,x='Airline',order=df['Airline'].value_counts().index,palette='light:#5A9')

# %% [markdown]
# #### Task: Histogram, Density plot, Box plot for Univariant - Numerical and Categorical.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 445366 entries, 0 to 452086
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Date_of_journey    445366 non-null  datetime64[ns]
#  1   Journey_day        445366 non-null  object
#  2   Airline            445366 non-null  object
#  3   Flight_code        445366 non-null  object
#  4   Class              445366 non-null  object
#  5   Source             445366 non-null  object
#  6   Departure          445366 non-null  object
#  7   Total_stops        445366 non-null  object
#  8   Arrival            445366 non-null  object
#  9   Destination        445366 non-null  object
#  10  Duration_in_hours  445366 non-null  float64
#  11  Days_left          445366 non-null  int64
#  12  Fare               445366 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(9)
# memory usage: 47.6+ MB

# %%
plt.figure(figsize=(10,5))
sns.countplot(df,x='Journey_day',order = df['Journey_day'].value_counts().index,palette = "blend:#7AB,#EDA")
plt.xlabel('Journey_day')
plt.ylabel('Frequency')
plt.title('Distribution of Journey_day')
plt.show()
# Out:
# /tmp/ipython-input-99-3074807419.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df,x='Journey_day',order = df['Journey_day'].value_counts().index,palette = "blend:#7AB,#EDA")

# %%
df['Flight_code'].value_counts()
# Out:
# Flight_code
# UK-936     5117
# UK-706     4957
# UK-918     4912
# UK-926     4388
# UK-832     4244
#            ...
# 6E-251        1
# 6E-3291       1
# 6E-6835       1
# G8-911        1
# 6E-983        1
# Name: count, Length: 1405, dtype: int64

# %%
plt.figure(figsize=(50,30))
sns.countplot(df,x='Flight_code',palette = "light:#5A9")
plt.xlabel('Flight_code')
plt.ylabel('Frequency')
plt.title('Distribution of Flight_code')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(df,x='Class',palette = 'flare')
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.title('Distribution of Class')
plt.show()
# Out:
# /tmp/ipython-input-103-3344414766.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df,x='Class',palette = 'flare')

# %%
plt.figure(figsize=(10,5))
sns.countplot(df,x='Source',palette = 'Spectral')
plt.xlabel('Source')
plt.ylabel('Frequency')
plt.title('Distribution of Source')
plt.show()
# Out:
# /tmp/ipython-input-104-2191569664.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df,x='Source',palette = 'Spectral')

# %%
plt.figure(figsize=(10,5))
sns.countplot(df,x='Departure',palette = "ch:s=.25,rot=-.25")
plt.xlabel('Departure')
plt.ylabel('Frequency')
plt.title('Distribution of Departure')
plt.show()
# Out:
# /tmp/ipython-input-107-3687629977.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df,x='Departure',palette = "ch:s=.25,rot=-.25")

# %%
plt.figure(figsize=(10,5))
sns.countplot(df,x='Total_stops',palette = "ch:s=.25,rot=-.25")
plt.xlabel('Total_stops')
plt.ylabel('Frequency')
plt.title('Distribution of Total_stops')
plt.show()
# Out:
# /tmp/ipython-input-108-3530052917.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df,x='Total_stops',palette = "ch:s=.25,rot=-.25")

# %%
plt.figure(figsize=(10,5))
sns.countplot(df,x='Arrival',palette = "dark:#5A9_r")
plt.xlabel('Arrival')
plt.ylabel('Frequency')
plt.title('Distribution of Arrival')
# Out:
# /tmp/ipython-input-109-2971428078.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df,x='Arrival',palette = "dark:#5A9_r")
# Text(0.5, 1.0, 'Distribution of Arrival')

# %%
plt.figure(figsize=(10,5))
sns.countplot(df,x='Destination',palette = "ch:s=.25,rot=-.25")
plt.xlabel('Destination')
plt.ylabel('Frequency')
plt.title('Distribution of Destination')
# Out:
# /tmp/ipython-input-111-4190659684.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df,x='Destination',palette = "ch:s=.25,rot=-.25")
# Text(0.5, 1.0, 'Distribution of Destination')
